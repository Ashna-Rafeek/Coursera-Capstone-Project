# %% [markdown]
# # Introduction

# %% [markdown]
# Restaurant business is considered to be stable if the demographics requirements are met. Especially, crowded metropolis areas require restaurants for busy people who work in the city and prefer dining-out than cooking at home. For our studies we are interested in Japanese cuisine as it is the favorite of big audiences, starting from vegans to people of any age. Location-wise Toronto is the most-populated city in Canada with over 6 million people in 2020 with the highest median salary of 123,000 CAD across the country. Thus it is believed that restaurant business goes well around the city. This study is going to analyze the best possible location for our Japanese Restaurant in Toronto, Canada so potential stakeholders could have great success and consistent profit.

# %% [markdown]
# # Business Problem

# %% [markdown]
# The objective of this project is to analyze and select the best locations in the city of Toronto, Canada to open a new Japanese restaurant. Utilizing data science methodology and instruments such as data analysis and data visualization project aims to provide solutions for our business problem: Where in Toronto, Canada should the investor open a Japanese Restaurant.

# %% [markdown]
# # Data Description

# %% [markdown]
# To proceed with studies we will be using the following data:
#     • Toronto, Canada data containing neighborhoods and boroughs
#     • Latitude and Longitude coordinates of these neighborhoods for plotting the map
#     • Venue data, namely restaurants data of Toronto

# %% [markdown]
# # Data Source

# %% [markdown]
# Toronto data source for neighborhoods and boroughs will be obtained from Wikipedia and wrangled with python pandas library. Further, we will retrieve geographical coordinates (latitude, longitude) from the website: http://cocl.us/Geospatial_data provided by IBM. Additionally, we are going to use Foursquare API to get venue data for the neighborhoods. Foursquare is one of the largest database for location data with over 100 million places. Foursquare API provides different categories of the venue data, particularly we are interested in restaurant data to find the solution to our business problem.

# %% [markdown]
# # 1. Libraries are downloaded to proceed to work with data

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 3.3 MB/s  eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.6.20)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests # library to handle requests

#from bs4 import BeautifulSoup
import os

import folium # map rendering library

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

import seaborn as sns

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # 1.1 Foursquare Credentials

# %%
CLIENT_ID = 'Q0FXNM3K4CCA5UXQHP5ZEK2WB2OLZ0ZDLJGIRFJBCB2YJT1M' # your Foursquare ID
CLIENT_SECRET = 'RO2434WPVRRKGNKBP121SMC2YA53G32DVRYLRYBSKXCEYC41' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# # 1.2 Download Data for Toronto, Canada

# %%
# First, we download html of Toronto boroughs into our notebook

pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# Secondly, we define our dataframe and assign it to pandas dataframe to have a clean look

toronto_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

# Thirdly, we drop Boroughs with Not assigned values
# And assign Borough names to Neighbourhoods with 'Not assigned' values

t_df = toronto_df[toronto_df.Borough != 'Not assigned'].reset_index().drop('index', axis=1)
for index, row in t_df.iterrows():
    if row['Neighbourhood'] == 'Not assigned':
        row['Neighbourhood'] = row['Borough']
        
# Here, we download csv of postal codes lattitude and longitude

latlong_df = pd.read_csv('http://cocl.us/Geospatial_data')

# Joining 2 Dataframes, namely Boroughs, Neighbourhoods with Lattitude, Longitude into 1

tor_df = t_df.set_index('Postal Code').sort_values(by='Postal Code')
ll_df = latlong_df.set_index('Postal Code').sort_values(by='Postal Code')
df_join = pd.concat([tor_df, ll_df], axis=1)
toronto_df = df_join.reset_index()
toronto_data = toronto_df.drop(['Postal Code'], axis=1)
toronto_data.head()
# Out:
#        Borough                           Neighbourhood   Latitude  Longitude
# 0  Scarborough                          Malvern, Rouge  43.806686 -79.194353
# 1  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2  Scarborough       Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3  Scarborough                                  Woburn  43.770992 -79.216917
# 4  Scarborough                               Cedarbrae  43.773136 -79.239476

# %% [markdown]
# # 1.3 Define Functions for further use in our Project

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude


def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
            pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# # 2. Data Analysis to find out number of Japanese Restaurants in Toronto

# %%
# Prepare neighborhood list that contains japanese restaurants

column_names=['Borough', 'Neighbourhood', 'ID','Name']
japanese_rest_t=pd.DataFrame(columns=column_names)
count=1
for row in toronto_data.values.tolist():
    Borough, Neighbourhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    japanese_restaurants=venues[venues['Category']=='Japanese Restaurant']   
    print('(',count,'/',len(toronto_data),')','Japanese Restaurants in '+Neighbourhood+', '+Borough+':'+str(len(japanese_restaurants)))
    print(row)
    for resturant_detail in japanese_restaurants.values.tolist():
        id, name , category=resturant_detail
        japanese_rest_t = japanese_rest_t.append({'Borough': Borough,
                                                'Neighbourhood': Neighbourhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 103 ) Japanese Restaurants in Malvern, Rouge, Scarborough:0
# ['Scarborough', 'Malvern, Rouge', 43.806686299999996, -79.19435340000001]
# ( 2 / 103 ) Japanese Restaurants in Rouge Hill, Port Union, Highland Creek, Scarborough:0
# ['Scarborough', 'Rouge Hill, Port Union, Highland Creek', 43.7845351, -79.16049709999999]
# ( 3 / 103 ) Japanese Restaurants in Guildwood, Morningside, West Hill, Scarborough:0
# ['Scarborough', 'Guildwood, Morningside, West Hill', 43.7635726, -79.1887115]
# ( 4 / 103 ) Japanese Restaurants in Woburn, Scarborough:0
# ['Scarborough', 'Woburn', 43.7709921, -79.21691740000001]
# ( 5 / 103 ) Japanese Restaurants in Cedarbrae, Scarborough:0
# ['Scarborough', 'Cedarbrae', 43.773136, -79.23947609999999]
# ( 6 / 103 ) Japanese Restaurants in Scarborough Village, Scarborough:0
# ['Scarborough', 'Scarborough Village', 43.7447342, -79.23947609999999]
# ( 7 / 103 ) Japanese Restaurants in Kennedy Park, Ionview, East Birchmount Park, Scarborough:0
# ['Scarborough', 'Kennedy Park, Ionview, East Birchmount Park', 43.7279292, -79.26202940000002]
# ( 8 / 103 ) Japanese Restaurants in Golden Mile, Clairlea, Oakridge, Scarborough:0
# ['Scarborough', 'Golden Mile, Clairlea, Oakridge', 43.711111700000004, -79.2845772]
# ( 9 / 103 ) Japanese Restaurants in Cliffside, Cliffcrest, Scarborough Village West, Scarborough:0
# ['Scarborough', 'Cliffside, Cliffcrest, Scarborough Village West', 43.716316, -79.23947609999999]
# ( 10 / 103 ) Japanese Restaurants in Birch Cliff, Cliffside West, Scarborough:0
# ['Scarborough', 'Birch Cliff, Cliffside West', 43.692657000000004, -79.2648481]
# ( 11 / 103 ) Japanese Restaurants in Dorset Park, Wexford Heights, Scarborough Town Centre, Scarborough:0
# ['Scarborough', 'Dorset Park, Wexford Heights, Scarborough Town Centre', 43.7574096, -79.27330400000001]
# ( 12 / 103 ) Japanese Restaurants in Wexford, Maryvale, Scarborough:0
# ['Scarborough', 'Wexford, Maryvale', 43.750071500000004, -79.2958491]
# ( 13 / 103 ) Japanese Restaurants in Agincourt, Scarborough:0
# ['Scarborough', 'Agincourt', 43.7942003, -79.26202940000002]
# ( 14 / 103 ) Japanese Restaurants in Clarks Corners, Tam O'Shanter, Sullivan, Scarborough:0
# ['Scarborough', "Clarks Corners, Tam O'Shanter, Sullivan", 43.7816375, -79.3043021]
# ( 15 / 103 ) Japanese Restaurants in Milliken, Agincourt North, Steeles East, L'Amoreaux East, Scarborough:0
# ['Scarborough', "Milliken, Agincourt North, Steeles East, L'Amoreaux East", 43.8152522, -79.2845772]
# ( 16 / 103 ) Japanese Restaurants in Steeles West, L'Amoreaux West, Scarborough:0
# ['Scarborough', "Steeles West, L'Amoreaux West", 43.799525200000005, -79.3183887]
# ( 17 / 103 ) Japanese Restaurants in Upper Rouge, Scarborough:0
# ['Scarborough', 'Upper Rouge', 43.836124700000006, -79.20563609999999]
# ( 18 / 103 ) Japanese Restaurants in Hillcrest Village, North York:0
# ['North York', 'Hillcrest Village', 43.8037622, -79.3634517]
# ( 19 / 103 ) Japanese Restaurants in Fairview, Henry Farm, Oriole, North York:3
# ['North York', 'Fairview, Henry Farm, Oriole', 43.7785175, -79.3465557]
# ( 20 / 103 ) Japanese Restaurants in Bayview Village, North York:0
# ['North York', 'Bayview Village', 43.7869473, -79.385975]
# ( 21 / 103 ) Japanese Restaurants in York Mills, Silver Hills, North York:0
# ['North York', 'York Mills, Silver Hills', 43.7574902, -79.37471409999999]
# ( 22 / 103 ) Japanese Restaurants in Willowdale, Newtonbrook, North York:0
# ['North York', 'Willowdale, Newtonbrook', 43.789053, -79.40849279999999]
# ( 23 / 103 ) Japanese Restaurants in Willowdale, Willowdale East, North York:1
# ['North York', 'Willowdale, Willowdale East', 43.7701199, -79.40849279999999]
# ( 24 / 103 ) Japanese Restaurants in York Mills West, North York:0
# ['North York', 'York Mills West', 43.752758299999996, -79.4000493]
# ( 25 / 103 ) Japanese Restaurants in Willowdale, Willowdale West, North York:0
# ['North York', 'Willowdale, Willowdale West', 43.7827364, -79.4422593]
# ( 26 / 103 ) Japanese Restaurants in Parkwoods, North York:0
# ['North York', 'Parkwoods', 43.7532586, -79.3296565]
# ( 27 / 103 ) Japanese Restaurants in Don Mills, North York:0
# ['North York', 'Don Mills', 43.745905799999996, -79.352188]
# ( 28 / 103 ) Japanese Restaurants in Don Mills, North York:1
# ['North York', 'Don Mills', 43.72589970000001, -79.340923]
# ( 29 / 103 ) Japanese Restaurants in Bathurst Manor, Wilson Heights, Downsview North, North York:0
# ['North York', 'Bathurst Manor, Wilson Heights, Downsview North', 43.7543283, -79.4422593]
# ( 30 / 103 ) Japanese Restaurants in Northwood Park, York University, North York:0
# ['North York', 'Northwood Park, York University', 43.7679803, -79.48726190000001]
# ( 31 / 103 ) Japanese Restaurants in Downsview, North York:0
# ['North York', 'Downsview', 43.737473200000004, -79.46476329999999]
# ( 32 / 103 ) Japanese Restaurants in Downsview, North York:0
# ['North York', 'Downsview', 43.7390146, -79.5069436]
# ( 33 / 103 ) Japanese Restaurants in Downsview, North York:0
# ['North York', 'Downsview', 43.7284964, -79.49569740000001]
# ( 34 / 103 ) Japanese Restaurants in Downsview, North York:0
# ['North York', 'Downsview', 43.7616313, -79.52099940000001]
# ( 35 / 103 ) Japanese Restaurants in Victoria Village, North York:0
# ['North York', 'Victoria Village', 43.725882299999995, -79.31557159999998]
# ( 36 / 103 ) Japanese Restaurants in Parkview Hill, Woodbine Gardens, East York:0
# ['East York', 'Parkview Hill, Woodbine Gardens', 43.7063972, -79.309937]
# ( 37 / 103 ) Japanese Restaurants in Woodbine Heights, East York:0
# ['East York', 'Woodbine Heights', 43.695343900000005, -79.3183887]
# ( 38 / 103 ) Japanese Restaurants in The Beaches, East Toronto:0
# ['East Toronto', 'The Beaches', 43.67635739999999, -79.2930312]
# ( 39 / 103 ) Japanese Restaurants in Leaside, East York:0
# ['East York', 'Leaside', 43.7090604, -79.3634517]
# ( 40 / 103 ) Japanese Restaurants in Thorncliffe Park, East York:0
# ['East York', 'Thorncliffe Park', 43.7053689, -79.34937190000001]
# ( 41 / 103 ) Japanese Restaurants in East Toronto, Broadview North (Old East York), East York:0
# ['East York', 'East Toronto, Broadview North (Old East York)', 43.685347, -79.3381065]
# ( 42 / 103 ) Japanese Restaurants in The Danforth West, Riverdale, East Toronto:0
# ['East Toronto', 'The Danforth West, Riverdale', 43.6795571, -79.352188]
# ( 43 / 103 ) Japanese Restaurants in India Bazaar, The Beaches West, East Toronto:0
# ['East Toronto', 'India Bazaar, The Beaches West', 43.6689985, -79.31557159999998]
# ( 44 / 103 ) Japanese Restaurants in Studio District, East Toronto:0
# ['East Toronto', 'Studio District', 43.6595255, -79.340923]
# ( 45 / 103 ) Japanese Restaurants in Lawrence Park, Central Toronto:0
# ['Central Toronto', 'Lawrence Park', 43.7280205, -79.3887901]
# ( 46 / 103 ) Japanese Restaurants in Davisville North, Central Toronto:0
# ['Central Toronto', 'Davisville North', 43.7127511, -79.3901975]
# ( 47 / 103 ) Japanese Restaurants in North Toronto West, Lawrence Park, Central Toronto:0
# ['Central Toronto', 'North Toronto West, Lawrence Park', 43.7153834, -79.40567840000001]
# ( 48 / 103 ) Japanese Restaurants in Davisville, Central Toronto:0
# ['Central Toronto', 'Davisville', 43.7043244, -79.3887901]
# ( 49 / 103 ) Japanese Restaurants in Moore Park, Summerhill East, Central Toronto:0
# ['Central Toronto', 'Moore Park, Summerhill East', 43.6895743, -79.38315990000001]
# ( 50 / 103 ) Japanese Restaurants in Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Central Toronto:0
# ['Central Toronto', 'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park', 43.68641229999999, -79.4000493]
# ( 51 / 103 ) Japanese Restaurants in Rosedale, Downtown Toronto:0
# ['Downtown Toronto', 'Rosedale', 43.6795626, -79.37752940000001]
# ( 52 / 103 ) Japanese Restaurants in St. James Town, Cabbagetown, Downtown Toronto:1
# ['Downtown Toronto', 'St. James Town, Cabbagetown', 43.667967, -79.3676753]
# ( 53 / 103 ) Japanese Restaurants in Church and Wellesley, Downtown Toronto:3
# ['Downtown Toronto', 'Church and Wellesley', 43.6658599, -79.38315990000001]
# ( 54 / 103 ) Japanese Restaurants in Regent Park, Harbourfront, Downtown Toronto:0
# ['Downtown Toronto', 'Regent Park, Harbourfront', 43.6542599, -79.3606359]
# ( 55 / 103 ) Japanese Restaurants in Garden District, Ryerson, Downtown Toronto:2
# ['Downtown Toronto', 'Garden District, Ryerson', 43.6571618, -79.37893709999999]
# ( 56 / 103 ) Japanese Restaurants in St. James Town, Downtown Toronto:2
# ['Downtown Toronto', 'St. James Town', 43.6514939, -79.3754179]
# ( 57 / 103 ) Japanese Restaurants in Berczy Park, Downtown Toronto:0
# ['Downtown Toronto', 'Berczy Park', 43.644770799999996, -79.3733064]
# ( 58 / 103 ) Japanese Restaurants in Central Bay Street, Downtown Toronto:3
# ['Downtown Toronto', 'Central Bay Street', 43.6579524, -79.3873826]
# ( 59 / 103 ) Japanese Restaurants in Richmond, Adelaide, King, Downtown Toronto:3
# ['Downtown Toronto', 'Richmond, Adelaide, King', 43.65057120000001, -79.3845675]
# ( 60 / 103 ) Japanese Restaurants in Harbourfront East, Union Station, Toronto Islands, Downtown Toronto:1
# ['Downtown Toronto', 'Harbourfront East, Union Station, Toronto Islands', 43.6408157, -79.38175229999999]
# ( 61 / 103 ) Japanese Restaurants in Toronto Dominion Centre, Design Exchange, Downtown Toronto:2
# ['Downtown Toronto', 'Toronto Dominion Centre, Design Exchange', 43.6471768, -79.38157640000001]
# ( 62 / 103 ) Japanese Restaurants in Commerce Court, Victoria Hotel, Downtown Toronto:2
# ['Downtown Toronto', 'Commerce Court, Victoria Hotel', 43.6481985, -79.37981690000001]
# ( 63 / 103 ) Japanese Restaurants in Bedford Park, Lawrence Manor East, North York:0
# ['North York', 'Bedford Park, Lawrence Manor East', 43.7332825, -79.4197497]
# ( 64 / 103 ) Japanese Restaurants in Roselawn, Central Toronto:0
# ['Central Toronto', 'Roselawn', 43.7116948, -79.41693559999999]
# ( 65 / 103 ) Japanese Restaurants in Forest Hill North & West, Forest Hill Road Park, Central Toronto:0
# ['Central Toronto', 'Forest Hill North & West, Forest Hill Road Park', 43.6969476, -79.41130720000001]
# ( 66 / 103 ) Japanese Restaurants in The Annex, North Midtown, Yorkville, Central Toronto:0
# ['Central Toronto', 'The Annex, North Midtown, Yorkville', 43.6727097, -79.40567840000001]
# ( 67 / 103 ) Japanese Restaurants in University of Toronto, Harbord, Downtown Toronto:1
# ['Downtown Toronto', 'University of Toronto, Harbord', 43.6626956, -79.4000493]
# ( 68 / 103 ) Japanese Restaurants in Kensington Market, Chinatown, Grange Park, Downtown Toronto:0
# ['Downtown Toronto', 'Kensington Market, Chinatown, Grange Park', 43.6532057, -79.4000493]
# ( 69 / 103 ) Japanese Restaurants in CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport, Downtown Toronto:0
# ['Downtown Toronto', 'CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport', 43.6289467, -79.3944199]
# ( 70 / 103 ) Japanese Restaurants in Stn A PO Boxes, Downtown Toronto:2
# ['Downtown Toronto', 'Stn A PO Boxes', 43.6464352, -79.37484599999999]
# ( 71 / 103 ) Japanese Restaurants in First Canadian Place, Underground city, Downtown Toronto:4
# ['Downtown Toronto', 'First Canadian Place, Underground city', 43.6484292, -79.3822802]
# ( 72 / 103 ) Japanese Restaurants in Lawrence Manor, Lawrence Heights, North York:0
# ['North York', 'Lawrence Manor, Lawrence Heights', 43.718517999999996, -79.46476329999999]
# ( 73 / 103 ) Japanese Restaurants in Glencairn, North York:1
# ['North York', 'Glencairn', 43.709577, -79.44507259999999]
# ( 74 / 103 ) Japanese Restaurants in Humewood-Cedarvale, York:0
# ['York', 'Humewood-Cedarvale', 43.6937813, -79.42819140000002]
# ( 75 / 103 ) Japanese Restaurants in Caledonia-Fairbanks, York:0
# ['York', 'Caledonia-Fairbanks', 43.6890256, -79.453512]
# ( 76 / 103 ) Japanese Restaurants in Christie, Downtown Toronto:0
# ['Downtown Toronto', 'Christie', 43.669542, -79.4225637]
# ( 77 / 103 ) Japanese Restaurants in Dufferin, Dovercourt Village, West Toronto:0
# ['West Toronto', 'Dufferin, Dovercourt Village', 43.66900510000001, -79.4422593]
# ( 78 / 103 ) Japanese Restaurants in Little Portugal, Trinity, West Toronto:1
# ['West Toronto', 'Little Portugal, Trinity', 43.647926700000006, -79.4197497]
# ( 79 / 103 ) Japanese Restaurants in Brockton, Parkdale Village, Exhibition Place, West Toronto:0
# ['West Toronto', 'Brockton, Parkdale Village, Exhibition Place', 43.6368472, -79.42819140000002]
# ( 80 / 103 ) Japanese Restaurants in North Park, Maple Leaf Park, Upwood Park, North York:0
# ['North York', 'North Park, Maple Leaf Park, Upwood Park', 43.713756200000006, -79.4900738]
# ( 81 / 103 ) Japanese Restaurants in Del Ray, Mount Dennis, Keelsdale and Silverthorn, York:0
# ['York', 'Del Ray, Mount Dennis, Keelsdale and Silverthorn', 43.6911158, -79.47601329999999]
# ( 82 / 103 ) Japanese Restaurants in Runnymede, The Junction North, York:0
# ['York', 'Runnymede, The Junction North', 43.67318529999999, -79.48726190000001]
# ( 83 / 103 ) Japanese Restaurants in High Park, The Junction South, West Toronto:0
# ['West Toronto', 'High Park, The Junction South', 43.6616083, -79.46476329999999]
# ( 84 / 103 ) Japanese Restaurants in Parkdale, Roncesvalles, West Toronto:0
# ['West Toronto', 'Parkdale, Roncesvalles', 43.6489597, -79.456325]
# ( 85 / 103 ) Japanese Restaurants in Runnymede, Swansea, West Toronto:0
# ['West Toronto', 'Runnymede, Swansea', 43.6515706, -79.4844499]
# ( 86 / 103 ) Japanese Restaurants in Queen's Park, Ontario Provincial Government, Downtown Toronto:0
# ['Downtown Toronto', "Queen's Park, Ontario Provincial Government", 43.6623015, -79.3894938]
# ( 87 / 103 ) Japanese Restaurants in Canada Post Gateway Processing Centre, Mississauga:0
# ['Mississauga', 'Canada Post Gateway Processing Centre', 43.6369656, -79.61581899999999]
# ( 88 / 103 ) Japanese Restaurants in Business reply mail Processing Centre, South Central Letter Processing Plant Toronto, East Toronto:0
# ['East Toronto', 'Business reply mail Processing Centre, South Central Letter Processing Plant Toronto', 43.6627439, -79.321558]
# ( 89 / 103 ) Japanese Restaurants in New Toronto, Mimico South, Humber Bay Shores, Etobicoke:0
# ['Etobicoke', 'New Toronto, Mimico South, Humber Bay Shores', 43.6056466, -79.50132070000001]
# ( 90 / 103 ) Japanese Restaurants in Alderwood, Long Branch, Etobicoke:0
# ['Etobicoke', 'Alderwood, Long Branch', 43.60241370000001, -79.54348409999999]
# ( 91 / 103 ) Japanese Restaurants in The Kingsway, Montgomery Road, Old Mill North, Etobicoke:0
# ['Etobicoke', 'The Kingsway, Montgomery Road, Old Mill North', 43.653653600000005, -79.5069436]
# ( 92 / 103 ) Japanese Restaurants in Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East, Etobicoke:0
# ['Etobicoke', "Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East", 43.6362579, -79.49850909999999]
# ( 93 / 103 ) Japanese Restaurants in Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West, Etobicoke:0
# ['Etobicoke', 'Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West', 43.6288408, -79.52099940000001]
# ( 94 / 103 ) Japanese Restaurants in Islington Avenue, Humber Valley Village, Etobicoke:0
# ['Etobicoke', 'Islington Avenue, Humber Valley Village', 43.6678556, -79.53224240000002]
# ( 95 / 103 ) Japanese Restaurants in West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale, Etobicoke:0
# ['Etobicoke', 'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale', 43.6509432, -79.55472440000001]
# ( 96 / 103 ) Japanese Restaurants in Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood, Etobicoke:0
# ['Etobicoke', 'Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood', 43.6435152, -79.57720079999999]
# ( 97 / 103 ) Japanese Restaurants in Humber Summit, North York:0
# ['North York', 'Humber Summit', 43.7563033, -79.56596329999999]
# ( 98 / 103 ) Japanese Restaurants in Humberlea, Emery, North York:0
# ['North York', 'Humberlea, Emery', 43.7247659, -79.53224240000002]
# ( 99 / 103 ) Japanese Restaurants in Weston, York:0
# ['York', 'Weston', 43.706876, -79.51818840000001]
# ( 100 / 103 ) Japanese Restaurants in Westmount, Etobicoke:0
# ['Etobicoke', 'Westmount', 43.696319, -79.53224240000002]
# ( 101 / 103 ) Japanese Restaurants in Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens, Etobicoke:0
# ['Etobicoke', 'Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens', 43.6889054, -79.55472440000001]
# ( 102 / 103 ) Japanese Restaurants in South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens, Etobicoke:0
# ['Etobicoke', 'South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens', 43.739416399999996, -79.5884369]
# ( 103 / 103 ) Japanese Restaurants in Northwest, West Humber - Clairville, Etobicoke:0
# ['Etobicoke', 'Northwest, West Humber - Clairville', 43.706748299999994, -79.5940544]

# %%
#japanese_rest_t.to_csv('japanese_rest_t_tocsv1.csv') # Save the information so far to a .csv file due to limited calls on FourSquare
japanese_rest_t.to_csv('japanese_rest_t_tocsv1.csv')

# %%
japanese_t = pd.read_csv('japanese_rest_t_tocsv1.csv')
japanese_rest_t.tail()
# Out:
#              Borough                           Neighbourhood  \
# 28  Downtown Toronto  First Canadian Place, Underground city
# 29  Downtown Toronto  First Canadian Place, Underground city
# 30  Downtown Toronto  First Canadian Place, Underground city
# 31        North York                               Glencairn
# 32      West Toronto                Little Portugal, Trinity
#
#                           ID                      Name
# 28  5a4fdf56772fbc5e9fa73c7f              Chotto Matte
# 29  506a3830e4b0677a1f9d8eda             Ninki Izakaya
# 30  4afa1f33f964a520e91622e3  Fune Japanese Restaurant
# 31  4fca732be4b07c8e3e198c27   Miyako Sushi Restaurant
# 32  51049684e4b06b57cac4e3e8                    Bazara

# %%
japanese_rest_t.shape
# Out:
# (33, 4)

# %%
japanese_rest_t.groupby('Borough')['ID'].count().plot.bar(figsize=(14,6), color='navy')
plt.title('Japanese Restaurants per Borough: Toronto, Canada', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. of Japanese Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
NOofNeigh = 6 # top number for graphing all the same past 6
japanese_rest_t.groupby('Neighbourhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(18,6), color='navy')
plt.title('Japanese Restaurants per Neighbourhood: Toronto, Canada', fontsize = 20)
plt.xlabel('Neighbourhood', fontsize = 15)
plt.ylabel('No. of Japanese Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %% [markdown]
# # 2.1 Rankings of the Found Restaurants

# %%
column_names=['Borough', 'Neighbourhood', 'ID','Name','Likes','Rating','Tips']
japanese_rest_stats_t=pd.DataFrame(columns=column_names)
count=1
for row in japanese_rest_t.values.tolist():
    Borough,Neighbourhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(japanese_rest_t),')','processed')
    japanese_rest_stats_t = japanese_rest_stats_t.append({'Borough': Borough,
                                                'Neighbourhood': Neighbourhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
japanese_rest_stats_t.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '5fc4ea2992d28855b93e58d6'}, 'response': {'venue': {'id': '5952e5ed491be7022cf5d19f', 'name': 'Heart Sushi', 'contact': {}, 'location': {'address': '1800 Sheppard Avenue E', 'lat': 43.777203, 'lng': -79.343805, 'labeledLatLngs': [{'label': 'display', 'lat': 43.777203, 'lng': -79.343805}], 'postalCode': 'M2J', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['1800 Sheppard Avenue E', 'Toronto ON M2J', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/heart-sushi/5952e5ed491be7022cf5d19f', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': [{'isSanctioned': False, 'firstName': 'WiD', 'countryCode': 'SA'}, {'isSanctioned': False, 'firstName': 'Izzy', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Ahmad', 'lastName': 'S', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Ashley', 'lastName': 'S', 'countryCode': 'CA'}]}], 'summary': '5 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.2, 'ratingColor': 'FFC800', 'ratingSignals': 11, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 96, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 96, 'items': [{'id': '5e6137b80b66dc0008e70583', 'createdAt': 1583429560, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1722659_vNcEU2D0Y4nzlihF64GOAHKN_UODZDexMNmbEEuk4Ik.jpg', 'width': 1080, 'height': 810, 'user': {'isSanctioned': False, 'firstName': 'Gor', 'lastName': 'W', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '5e6137b7c97e020008893a18', 'createdAt': 1583429559, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1722659_Q50tgAU7shfMA6_ivBZ70X5AvijGN5ftKIB3qh5HOt8.jpg', 'width': 1080, 'height': 810, 'user': {'isSanctioned': False, 'firstName': 'Gor', 'lastName': 'W', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1498605037, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5c3a943db3c961002cd2a415', 'createdAt': 1547342909, 'text': 'Best all you can eat lunch menu for less than 20$. Love this place.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c3a943db3c961002cd2a415', 'photo': {'id': '5c3a943f3ba767002c26bc54', 'createdAt': 1547342911, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/8766224_nXlvvNAHSHOYnHr870B6T-z9SpsCcnXY8B6ZEXJgE9A.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/8766224_nXlvvNAHSHOYnHr870B6T-z9SpsCcnXY8B6ZEXJgE9A.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Izzy', 'countryCode': 'CA'}, 'authorInteractionType': 'liked'}, {'id': '5aaee8f61acf113754a88dba', 'createdAt': 1521412342, 'text': "The sushi is okay for the ayce lunch menu, but their hot foods are bomb. Honestl ...
#                          ID         Name  Likes  Rating  Tips
# 0  5952e5ed491be7022cf5d19f  Heart Sushi      5     6.2     3
# ( 1 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2af55f360d589529b9'}, 'response': {'venue': {'id': '4be1b4df8c2bc9b6e4c0420b', 'name': 'Teriyaki Experience', 'contact': {'phone': '4169986297', 'formattedPhone': '(416) 998-6297'}, 'location': {'address': '1800 Sheppard Ave. E', 'lat': 43.77832992258357, 'lng': -79.34310953832035, 'labeledLatLngs': [{'label': 'display', 'lat': 43.77832992258357, 'lng': -79.34310953832035}], 'postalCode': 'M2J 5A7', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['1800 Sheppard Ave. E', 'Toronto ON M2J 5A7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/teriyaki-experience/4be1b4df8c2bc9b6e4c0420b', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 1}, 'url': 'https://www.teriyakiexperience.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Kelli', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Ashley', 'countryCode': 'CA'}]}], 'summary': '2 Likes'}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 5, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 5, 'items': [{'id': '53568b74498e3ba4a0897161', 'createdAt': 1398180724, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2597_109dYDTZfXshkvjIxpzb6T1aUU_5jd1lNdfffUX4gko.jpg', 'width': 960, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Rui', 'lastName': 'P', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '51b78d70498ec4c6f8c2227d', 'createdAt': 1370983792, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/48907153_TvMFVymqpxD_KeNk6Dc9sTV7wXjPvcvMmW2BmRZcVeY.jpg', 'width': 720, 'height': 960, 'user': {'isSanctioned': False, 'firstName': 'Happy', 'lastName': 'H', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'Since 1986 Teriyaki Experience has been a trailblazer within the fast food market, providing Japanese-inspired food that is both flavourful and healthy. Each guest enjoys a unique experience as each meal is made right before their eyes on a traditional teppanyaki grill.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1273083103, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '5592f5fb498eb9d162213262', 'createdAt': 1435694587, 'text': 'Yummy as always, but a little cheap on meat portions..', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5592f5fb498eb9d162213262', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Kelli', 'countryCode': 'CA'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/8ZFBV9', 'timeZone': 'America/Toronto', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'hours': {'status': 'Closed until 11:00 AM', 'richStatus': {'entities': [], 'text': 'Closed until 11:00 AM'}, 'isOpen': False, 'isLocalHoliday': False, 'dayData': [], 'timeframes': [{'days': 'Mon–Fri', 'includesToday': True, 'open': [{'renderedTime': '11:00 AM–9:00 PM'}], 'segments': []}, {'days': 'Sat', 'open': [{'renderedTime': '10:00 AM–9:00 PM'}], 'segments': []}, {'days': 'Sun', 'open': [ ...
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4be1b4df8c2bc9b6e4c0420b
# ( 2 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2a6e59ad4ec7385099'}, 'response': {'venue': {'id': '5a036eaf588e3631c784b5ba', 'name': 'Yoi', 'contact': {'phone': '4168668896', 'formattedPhone': '(416) 866-8896'}, 'location': {'address': '1800 Sheppard Ave West', 'crossStreet': 'Don Mills Rd', 'lat': 43.778244, 'lng': -79.34301, 'labeledLatLngs': [{'label': 'display', 'lat': 43.778244, 'lng': -79.34301}], 'postalCode': 'M2J 5A7', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['1800 Sheppard Ave West (Don Mills Rd)', 'Toronto ON M2J 5A7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/yoi/5a036eaf588e3631c784b5ba', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '55a59bace4b013909087cb24', 'name': 'Ramen Restaurant', 'pluralName': 'Ramen Restaurants', 'shortName': 'Ramen', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 0}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 2, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 2, 'items': [{'id': '5dd484dcd9a1dc0008e52f6b', 'createdAt': 1574208732, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/142711075_tChnoehbvXDQnQNU7sINvhq6eqeN_S5QmVzO9URWZJs.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Telnaz', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '5af3894ad69ed00039f89909', 'createdAt': 1525909834, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37352715_vSn3_4LbUMUI03e5Ed_MkLr9Is5LjUmyBXLh-OmsxFM.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Anna', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1510174383, 'tips': {'count': 0, 'groups': []}, 'shortUrl': 'http://4sq.com/2zHlhZt', 'timeZone': 'America/Toronto', 'listed': {'count': 1, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1, 'items': [{'id': '5c47291e59c423002c100268', 'name': 'Top 75 Restaurants by TTC Subway Stations', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Elizabeth', 'lastName': 'V', 'countryCode': 'CA'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/emviolante/list/top-75-restaurants-by-ttc-subway-stations', 'canonicalUrl': 'https://foursquare.com/emviolante/list/top-75-restaurants-by-ttc-subway-stations', 'createdAt': 1548167454, 'updatedAt': 1597081069, 'followers': {'count': 0}, 'listItems': {'count': 87, 'items': [{'id': 'v5a036eaf588e3631c784b5ba', 'createdAt': 1548169471}]}}]}]}, 'seasonalHours': [], 'pageUpdates': {'count': 0, 'items': []}, 'inbox': {'count': 0, 'items': []}, 'parent': {'id': '4ada3af3f964a520482021e3', 'name': 'CF Fairview Mall', 'location': {'address': '1800 Sheppard Ave E', 'crossStreet': 'at Don Mills Rd', 'lat': 43.77798094562394, 'lng': -79.3443966988859, 'postalCode': 'M2J 5A7', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['1800 Sheppard Ave E (at Don Mills Rd)', 'Toronto ON M2J 5A7', 'Canada']}, 'categories': [{'id': '4bf58dd8d48988d1fd941735', 'name': 'Shopping Mall', 'pluralName': 'Shopping Malls', 'shortName': 'Mall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/sh ...
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 5a036eaf588e3631c784b5ba
# ( 3 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2afa2a142aa6dca6f2'}, 'response': {'venue': {'id': '5077025ce4b05aefca37d9f9', 'name': 'Wako Sushi + Bar', 'contact': {'phone': '4165514476', 'formattedPhone': '(416) 551-4476'}, 'location': {'address': '5213 Yonge Street', 'lat': 43.77080606720809, 'lng': -79.41313811956255, 'labeledLatLngs': [{'label': 'display', 'lat': 43.77080606720809, 'lng': -79.41313811956255}], 'cc': 'CA', 'city': 'North York', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['5213 Yonge Street', 'North York ON', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/wako-sushi--bar/5077025ce4b05aefca37d9f9', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d11c941735', 'name': 'Sake Bar', 'pluralName': 'Sake Bars', 'shortName': 'Sake Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 4}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.0, 'ratingColor': 'C5DE35', 'ratingSignals': 20, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '5d4dd06f3d4ea600084ae1e3', 'createdAt': 1565380719, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/125818476_NIYT3J-GjrTTqQ_-DwQar5d5HB7dluqgfzWpqwvLTD8.jpg', 'width': 1582, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Sofía', 'lastName': 'G', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '5d02e7a1c0cacb002c511e16', 'createdAt': 1560471457, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/125818476_BT_VpvjwChbULItyAauLVMczgLGccMrgEKTt44Pogwg.jpg', 'width': 1079, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Sofía', 'lastName': 'G', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1349976668, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5d6d38374f76a6000621d05a', 'createdAt': 1567438903, 'text': 'Their sashimi is great', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d6d38374f76a6000621d05a', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Harley', 'lastName': 'L', 'countryCode': 'CA'}, 'authorInteractionType': 'liked'}, {'id': '54694fe5498e2bf1a1828bdf', 'createdAt': 1416187877, 'text': 'Orange dragon roll is delicious!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54694fe5498e2bf1a1828bdf', 'photo': {'id': '54694fe6498e14a1a9d17b89', 'createdAt': 1416187878, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/28340466_n3XjH6s7OJdGaBW4eM5_QRB6rPnpBpTw0k0bFkKkBus.jpg', 'width': 720, 'height': 720, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/28340466_n3XjH6s7OJdGaBW4eM5_QRB6rPnpBpTw0k0bFkKkBus.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'HanBi', 'lastName': 'K', 'countryCode': 'CA'}}] ...
#                          ID              Name  Likes  Rating  Tips
# 0  5077025ce4b05aefca37d9f9  Wako Sushi + Bar     12     7.0     4
# ( 4 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2a11398a33e7aa086c'}, 'response': {'venue': {'id': '4aec790bf964a5208fc721e3', 'name': 'Memories of Japan', 'contact': {'phone': '4164493773', 'formattedPhone': '(416) 449-3773'}, 'location': {'address': '900 Don Mills Rd', 'lat': 43.727078, 'lng': -79.340794, 'labeledLatLngs': [{'label': 'display', 'lat': 43.727078, 'lng': -79.340794}], 'postalCode': 'M3C 1V6', 'cc': 'CA', 'city': 'North York', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['900 Don Mills Rd', 'North York ON M3C 1V6', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/memories-of-japan/4aec790bf964a5208fc721e3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 32}, 'url': 'http://memoriesofjapan.ca', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 36, 'groups': [{'type': 'others', 'count': 36, 'items': []}], 'summary': '36 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.8, 'ratingColor': 'FFC800', 'ratingSignals': 70, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 71, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 71, 'items': [{'id': '50e72d13e4b0c220c1df75e7', 'createdAt': 1357327635, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5886411_tO5aAwmSCG5v0_9QBnJkbIXIU0BhmwwGwsAMQV6d4A8.jpg', 'width': 612, 'height': 612, 'user': {'isSanctioned': False, 'firstName': 'Amira', 'lastName': 'D', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '51fd9fa6498e8316360412c7', 'createdAt': 1375575974, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/21710624_KpxrdPP-g8HJmGYPAzRe81QG1iEzVLsamhsRPoWjdLE.jpg', 'width': 960, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Jean', 'lastName': 'Y', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'When you’re craving delicious and authentic Japanese cuisine, come visit Memories of Japan in North York. With room for over 300 diners we have been one of the largest Japanese restaurants in all of Ontario for over 15 years...', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1257011467, 'tips': {'count': 32, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 32, 'items': [{'id': '4b1ad0ff70c603bb9f418fb4', 'createdAt': 1260048639, 'text': 'I remembered japan so hard here. it was awesome!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4b1ad0ff70c603bb9f418fb4', 'lang': 'en', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'isSanctioned': False, 'firstName': 'Éléphant soulier', 'countryCode': 'CA'}]}], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'joshua', 'lastName': 'h', 'countryCode': 'CA'}}, {'id': '51b670f6498e4f3e5e8c4072', 'createdAt': 1370910966, 'text': 'Sushi and grill are amazing!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51b670f6498e4f3e5e8c4072', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': 'Hanna', 'lastName': ' ...
#                          ID               Name  Likes  Rating  Tips
# 0  4aec790bf964a5208fc721e3  Memories of Japan     36     6.8    32
# ( 5 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2b01f51442ca9c5d10'}, 'response': {'venue': {'id': '50cc21c37ab4d9c0594b6994', 'name': 'Kingyo Toronto', 'contact': {'phone': '6477482121', 'formattedPhone': '(647) 748-2121', 'twitter': 'kingyotoronto', 'facebook': '762851630440748', 'facebookUsername': 'Kingyotoronto', 'facebookName': 'Kingyo Izakaya Toronto'}, 'location': {'address': '51B Winchester St.', 'crossStreet': 'at Broadcast Ln.', 'lat': 43.66589495808371, 'lng': -79.36841520638596, 'labeledLatLngs': [{'label': 'display', 'lat': 43.66589495808371, 'lng': -79.36841520638596}], 'postalCode': 'M4X 1R7', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['51B Winchester St. (at Broadcast Ln.)', 'Toronto ON M4X 1R7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/kingyo-toronto/50cc21c37ab4d9c0594b6994', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 55}, 'url': 'http://kingyotoronto.ca', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 113, 'groups': [{'type': 'others', 'count': 113, 'items': []}], 'summary': '113 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 161, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/kingyo-toronto/50cc21c37ab4d9c0594b6994/menu', 'mobileUrl': 'https://foursquare.com/v/50cc21c37ab4d9c0594b6994/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 262, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 262, 'items': [{'id': '51d39261498ee27476af3ce8', 'createdAt': 1372820065, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/41489865_4ExybTxHItotp9hgVr5vCn1DU-POoFvxKKXF-QjLGPM.jpg', 'width': 720, 'height': 960, 'user': {'isSanctioned': False, 'firstName': 'Catherine', 'lastName': 'H', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '50f8cccce4b0d55daf1d856f', 'createdAt': 1358482636, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/21026915_1Wp4jxbCOFtUC0L8byEMx1e-949u4qcrB-kI7N4rM1A.jpg', 'width': 612, 'height': 612, 'user': {'isSanctioned': False, 'firstName': 'Adrienne', 'lastName': 'L', 'countryCode': 'HK'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Kingyo Toronto opened it’s doors in Toronto. We were delighted by the turnout and are looking forward to meeting many new friends. Please come by and say hello and enjoy our diverse menu and drink selection.', 'storeId': '', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1355555267, 'tips': {'count': 55, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 55, 'items': [{'id': '51d3c0ca498e712dda1fe91b', 'createdAt': 1372831946, 'text': 'Food was amazing service was great', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51d3c0ca498e712dda1fe91b', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'isSanctioned': False, 'firstName': 'IAM Group', 'lastName': 'L', 'countryCode': 'PH'}, {'isSanctioned': False, 'firstName': 'Wendy', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Rod', 'lastName': 'L', 'countryCode': 'MX'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': F ...
#                          ID            Name  Likes  Rating  Tips
# 0  50cc21c37ab4d9c0594b6994  Kingyo Toronto    113     8.4    55
# ( 6 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2bfb7a6b72ef4be4a4'}, 'response': {'venue': {'id': '4c193c77838020a1e768e561', 'name': 'Kawa Sushi', 'contact': {'phone': '4169212888', 'formattedPhone': '(416) 921-2888'}, 'location': {'address': '451 Church St.', 'lat': 43.66389438938988, 'lng': -79.38021009464505, 'labeledLatLngs': [{'label': 'display', 'lat': 43.66389438938988, 'lng': -79.38021009464505}], 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['451 Church St.', 'Toronto ON', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/kawa-sushi/4c193c77838020a1e768e561', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 13}, 'url': 'http://kawasushi.ca', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 27, 'groups': [{'type': 'others', 'count': 27, 'items': []}], 'summary': '27 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.7, 'ratingColor': 'C5DE35', 'ratingSignals': 43, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/kawa-sushi/4c193c77838020a1e768e561/menu', 'mobileUrl': 'https://foursquare.com/v/4c193c77838020a1e768e561/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 30, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 30, 'items': [{'id': '4f3845a6e4b02a70e22dbf6e', 'createdAt': 1329087910, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/0hgcAzu7IL_izxn8KNy-HSY1gq6bh0faKNjAGeOxUs4.jpg', 'width': 537, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Gus', 'lastName': 'B', 'countryCode': 'US'}, 'visibility': 'public'}, {'id': '51d75121498e1458189fbc20', 'createdAt': 1373065505, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/55651229_IMEJyuB_9S0bZ8IFYvW__wZMuJi6THTTQQR3eUQP2G8.jpg', 'width': 960, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Joshua', 'lastName': 'C', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1276722295, 'tips': {'count': 13, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 13, 'items': [{'id': '5237ab6f11d2e4d4a15f9d27', 'createdAt': 1379380079, 'text': 'We recommend the Dinner for 2/Dinner for 4.  Fantastic amount of sushi/sashimi, miso soup, etc...for a very reasonable price.  Plus warm, friendly, and efficient service!  1 of our favourite venues!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5237ab6f11d2e4d4a15f9d27', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Andrey', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Alicia', 'lastName': 'B', 'countryCode': 'CA'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Jonny', 'lastName': 'B', 'countryCode': 'CA'}, 'authorInteractionType': 'liked'}, {'id': '4feb4158e4b0676927a7af0f', 'createdAt': 1340817752, 'text': "PRIDE 2012 TIP: Seating here is very limited, but their takeout is fast. Carefully made sushi at a reasonable price is what Kawa is known for. Try the salad rolls if you're going rice-free.", 'type': 'user', 'url': 'http://shyndyg.com', 'canonicalUrl': 'https://foursquare.com/item/4feb4158e4b0676927a7af0f', 'lang': 'en', 'likes': {'c ...
#                          ID        Name  Likes  Rating  Tips
# 0  4c193c77838020a1e768e561  Kawa Sushi     27     7.7    13
# ( 7 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2b46cb367b6ea28d65'}, 'response': {'venue': {'id': '4ae787b9f964a52020ac21e3', 'name': 'Tokyo Kitchen', 'contact': {'phone': '4165150387', 'formattedPhone': '(416) 515-0387'}, 'location': {'address': 'Charles St.', 'crossStreet': 'at Yonge St.', 'lat': 43.66878262373862, 'lng': -79.38515305215851, 'labeledLatLngs': [{'label': 'display', 'lat': 43.66878262373862, 'lng': -79.38515305215851}], 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['Charles St. (at Yonge St.)', 'Toronto ON', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tokyo-kitchen/4ae787b9f964a52020ac21e3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 22}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 21, 'groups': [{'type': 'others', 'count': 21, 'items': []}], 'summary': '21 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 39, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 32, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 32, 'items': [{'id': '567b4146498e977a9a1d283b', 'createdAt': 1450918214, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/32043389_IF2JTXiI36_vB9vyJ8bLrmu6Se2MlEBkSHtjFO2TDvQ.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'E', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '560b0a64498eb578cfe81cf4', 'createdAt': 1443564132, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37748477_fCi3DVUr-HF6_wDCHaGFxgMKrwZ0klnDtWM8LiKDtVo.jpg', 'width': 1080, 'height': 1080, 'user': {'isSanctioned': False, 'firstName': 'J', 'lastName': 'H', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1256687545, 'tips': {'count': 22, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 22, 'items': [{'id': '532f69e611d24d9ee3fb8be6', 'createdAt': 1395616230, 'text': 'One word... croquette!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/532f69e611d24d9ee3fb8be6', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Jamie', 'lastName': 'S', 'countryCode': 'SK'}, {'isSanctioned': False, 'firstName': 'Björn', 'lastName': 'G', 'countryCode': 'DE'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Jacqueline', 'lastName': 'T', 'countryCode': 'CA'}}, {'id': '4dcf1831cc3f07eb1f0c25e2', 'createdAt': 1305417777, 'text': 'The croquettes here are great. Also, try the chicken katsu curry. I wish this place had late business hours.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4dcf1831cc3f07eb1f0c25e2', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': []}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Carolyn', 'lastName': 'V', 'countryCode': 'CA'}}]}]}, 'shortUrl': 'http://4sq.com/aQkfyE', 'timeZone': 'America/Toronto', 'listed': {'count': 16, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 16, 'items': [{'id': '5316113a498e33cca3347080', 'name': 'Toronto', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName':  ...
#                          ID           Name  Likes  Rating  Tips
# 0  4ae787b9f964a52020ac21e3  Tokyo Kitchen     21     7.5    22
# ( 8 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2c08692b75e6eeb655'}, 'response': {'venue': {'id': '4c531b60a724e21e029e3af4', 'name': 'Kokoni Izakaya', 'contact': {'phone': '6473460886', 'formattedPhone': '(647) 346-0886'}, 'location': {'address': '459 Church St', 'crossStreet': 'Alexander St', 'lat': 43.664181433817156, 'lng': -79.38025833040214, 'labeledLatLngs': [{'label': 'display', 'lat': 43.664181433817156, 'lng': -79.38025833040214}], 'postalCode': 'M4Y 2C5', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['459 Church St (Alexander St)', 'Toronto ON M4Y 2C5', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/kokoni-izakaya/4c531b60a724e21e029e3af4', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 9}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': 'Michael', 'lastName': 'S', 'countryCode': 'CA'}]}], 'summary': '1 Like'}, 'dislike': False, 'ok': False, 'rating': 6.6, 'ratingColor': 'FFC800', 'ratingSignals': 10, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 15, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 15, 'items': [{'id': '51b50fd2498e71ddf6105c23', 'createdAt': 1370820562, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/45677096_8uHGqMGPhAlGTcEh4cKwhk5HqUkLbTs_OW0HvPfcB30.jpg', 'width': 720, 'height': 960, 'user': {'isSanctioned': False, 'firstName': 'Michael', 'lastName': 'S', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '517af7aee4b00f3e026b3374', 'createdAt': 1367013294, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/45113703_VyseCKgr65hWNRk5J3KQCTRu6yAJzE7Jomr1MHbqX7M.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Daniel', 'lastName': 'J', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1280514912, 'tips': {'count': 9, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 9, 'items': [{'id': '4c810887d6ebbfb784f140a4', 'createdAt': 1283524743, 'text': "Kokoni is a tiny spot on Church that turns into a dance club at night, but don't let that affect your opinion of their small plates/bites/things on sticks. A. List tip? Deep-fried octopus balls.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4c810887d6ebbfb784f140a4', 'lang': 'en', 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': []}], 'summary': '8 likes'}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 14}, 'user': {'isSanctioned': False, 'firstName': 'AskMen', 'countryCode': 'US', 'type': 'page'}}, {'id': '4d2f76bc63302c0f46a645be', 'createdAt': 1294956220, 'text': 'Clearly the best sushi in the village.I recommend the Kamikaze roll.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4d2f76bc63302c0f46a645be', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': []}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'isSanctioned': False, 'firstName': 'Polaroid', 'lastName': 'M', 'countryCode': 'CA'}}]}]}, 'shortUrl': 'http://4sq.com/9pwFoX', 'timeZone': 'America/Toronto', 'listed': {'count': 6, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'cou ...
#                          ID            Name  Likes  Rating  Tips
# 0  4c531b60a724e21e029e3af4  Kokoni Izakaya      1     6.6     9
# ( 9 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2c543f107c69482ccb'}, 'response': {'venue': {'id': '4b2bd898f964a52042bc24e3', 'name': 'Kinka Izakaya Original', 'contact': {'phone': '4169770999', 'formattedPhone': '(416) 977-0999', 'twitter': 'kinkaizakayato', 'facebook': '160204064034815', 'facebookUsername': 'KinkaIzakayaToronto', 'facebookName': 'KINKA IZAKAYA TORONTO'}, 'location': {'address': '398 Church St', 'crossStreet': 'McGill Street', 'lat': 43.66059636632361, 'lng': -79.37889120754515, 'labeledLatLngs': [{'label': 'display', 'lat': 43.66059636632361, 'lng': -79.37889120754515}], 'postalCode': 'M5B 2A2', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['398 Church St (McGill Street)', 'Toronto ON M5B 2A2', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/kinka-izakaya-original/4b2bd898f964a52042bc24e3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d11c941735', 'name': 'Sake Bar', 'pluralName': 'Sake Bars', 'shortName': 'Sake Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 220}, 'url': 'http://www.kinka.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 385, 'groups': [{'type': 'others', 'count': 385, 'items': []}], 'summary': '385 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 592, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.kinkaizakaya.com/img/menu/church_menu/kinka1_food.pdf', 'mobileUrl': 'http://www.kinkaizakaya.com/img/menu/church_menu/kinka1_food.pdf', 'externalUrl': 'http://www.kinkaizakaya.com/img/menu/church_menu/kinka1_food.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 644, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 644, 'items': [{'id': '56707a00498e16c67cca8d0c', 'createdAt': 1450211840, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/148995305_y-yu7IHjx4IIfJ51v0NeXgi1ahoDUn1CCwwAw0dMVl4.jpg', 'width': 1400, 'height': 1099, 'user': {'isSanctioned': False, 'firstName': 'KINKA IZAKAYA TORONTO', 'countryCode': 'CA', 'type': 'chain'}, 'visibility': 'public'}, {'id': '567079db498e16c67cca8a4a', 'createdAt': 1450211803, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/148995305_ZokFFznSPs51GSLv22VRKfmxK1LFbV6hZyqLcaCA0Tk.jpg', 'width': 960, 'height': 910, 'user': {'isSanctioned': False, 'firstName': 'KINKA IZAKAYA TORONTO', 'countryCode': 'CA', 'type': 'chain'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Japanese-style pub.', 'storeId': '', 'page': {'pageInfo': {'description': 'Japanese-style pub', 'links': {'count': 1, 'items': [{'url': 'http://www.kinka.com'}]}}, 'user': {'isSanctioned': False, 'firstName': 'KINKA IZAKAYA TORONTO', 'countryCode': 'CA', 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1261164696, 'tips': {'count': 220, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 220, 'items': [{'id': '4c05601e70c603bb97f39 ...
#                          ID                    Name  Likes  Rating  Tips
# 0  4b2bd898f964a52042bc24e3  Kinka Izakaya Original    385     8.5   220
# ( 10 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea2c1edf443c9eaacbec'}, 'response': {'venue': {'id': '599cb69eb5461876d54ab713', 'name': 'Katsuya', 'contact': {}, 'location': {'address': '66 Gerrard St E', 'lat': 43.65986035759321, 'lng': -79.37878806223506, 'labeledLatLngs': [{'label': 'display', 'lat': 43.65986035759321, 'lng': -79.37878806223506}], 'postalCode': 'M5B 1G3', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['66 Gerrard St E', 'Toronto ON M5B 1G3', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/katsuya/599cb69eb5461876d54ab713', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 14, 'groups': [{'type': 'others', 'count': 14, 'items': []}], 'summary': '14 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.1, 'ratingColor': 'C5DE35', 'ratingSignals': 21, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 16, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 16, 'items': [{'id': '59e93fe7da2e006b4de69dbd', 'createdAt': 1508458471, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/12743882_bYoGFv1L8_zF6tkEiGyba4uaA1XbtW26oemgltEcqhw.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Chris', 'lastName': 'Z', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '59a7037fccad6b71221b80f1', 'createdAt': 1504117631, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2521756_vuKo_2qyIPtWG1d-g4rv4W3nxZo7FJ-6OhZxnxjV6Vo.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Jenn', 'lastName': 'K', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1503442590, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5b0c9f2b86f4cc002b02d05e', 'createdAt': 1527553835, 'text': 'Big portions.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5b0c9f2b86f4cc002b02d05e', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Jerry', 'lastName': 'M', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}, {'id': '5a01c952a0215b1bdb549022', 'createdAt': 1510066514, 'text': 'Thanks for high quality fresh food.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5a01c952a0215b1bdb549022', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Peter', 'lastName': 'Y', 'countryCode': 'IN'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2xqR8Zz', 'timeZone': 'America/Toronto', 'listed': {'count': 10, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 10, 'items': [{'id': '57ae9dc1498e3852958f176d', 'name': 'トロント', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Kobie', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/56807089/list/%E3%83%88%E3%83%AD%E3%83%B3%E3%83%88', 'canonicalUrl': 'https://foursquare.com/user/56807089/list/%E3%83%88%E3%83%AD%E3%83%B3%E3%83%88', 'createdAt': 1471061441, 'updatedAt': 1564527282, 'photo': {'id': '51562e5 ...
#                          ID     Name  Likes  Rating  Tips
# 0  599cb69eb5461876d54ab713  Katsuya     14     7.1     3
# ( 11 / 33 ) processed
# ...
#                          ID           Name  Likes  Rating  Tips
# 0  506a3830e4b0677a1f9d8eda  Ninki Izakaya      9     7.6     5
# ( 30 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea320525d44519387a68'}, 'response': {'venue': {'id': '4afa1f33f964a520e91622e3', 'name': 'Fune Japanese Restaurant', 'contact': {'phone': '4165993868', 'formattedPhone': '(416) 599-3868'}, 'location': {'address': '100 Simcoe St.', 'crossStreet': 'at Pearl St.', 'lat': 43.64851365544565, 'lng': -79.38645657820041, 'labeledLatLngs': [{'label': 'display', 'lat': 43.64851365544565, 'lng': -79.38645657820041}], 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['100 Simcoe St. (at Pearl St.)', 'Toronto ON', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/fune-japanese-restaurant/4afa1f33f964a520e91622e3', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 27}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 53, 'groups': [{'type': 'others', 'count': 53, 'items': []}], 'summary': '53 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 84, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/fune-japanese-restaurant/4afa1f33f964a520e91622e3/menu', 'mobileUrl': 'https://foursquare.com/v/4afa1f33f964a520e91622e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 97, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 97, 'items': [{'id': '533b6747498e5677d23ffec7', 'createdAt': 1396401991, 'source': {'name': 'Windows Phone 8', 'url': 'http://claritycon.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/82715661_CWydo2ydcKs42A6a016-TrfMiOCd4P_z5epUy83Rigc.jpg', 'width': 960, 'height': 540, 'user': {'isSanctioned': False, 'firstName': 'Luis Javier', 'lastName': 'R', 'countryCode': 'MX'}, 'visibility': 'public'}, {'id': '52543fe7498ee2a28295535f', 'createdAt': 1381253095, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3963468_1zxs30IQF9E0jNhVoBS_xuy2_gA3tLEzv0OxW1aVKNo.jpg', 'width': 640, 'height': 640, 'user': {'isSanctioned': False, 'firstName': 'Katie', 'lastName': 'P', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1257905971, 'tips': {'count': 27, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 27, 'items': [{'id': '512775b2e4b061d508215c0e', 'createdAt': 1361540530, 'text': 'Really enjoyed our meal here. Get cozy by the sushi bar!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/512775b2e4b061d508215c0e', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Patrick', 'lastName': 'L', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': '@ShawnyP23', 'countryCode': 'CA'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': '@ShawnyP23', 'countryCode': 'CA'}}, {'id': '54888342498e7a42506ebe73', 'createdAt': 1418232642, 'text': "The sushi boats look great, but as someone who doesn't like seafood, they also have fantastic Chicken Teriyaki with grilled vegetables.", 'type': 'user', 'canonicalUrl': 'https://foursqua ...
#                          ID                      Name  Likes  Rating  Tips
# 0  4afa1f33f964a520e91622e3  Fune Japanese Restaurant     53     7.6    27
# ( 31 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea32fa2a142aa6dcc0ac'}, 'response': {'venue': {'id': '4fca732be4b07c8e3e198c27', 'name': 'Miyako Sushi Restaurant', 'contact': {}, 'location': {'address': '572 Marlee Ave', 'crossStreet': 'at Glencairn Ave', 'lat': 43.709111, 'lng': -79.44393, 'labeledLatLngs': [{'label': 'display', 'lat': 43.709111, 'lng': -79.44393}], 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['572 Marlee Ave (at Glencairn Ave)', 'Toronto ON', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/miyako-sushi-restaurant/4fca732be4b07c8e3e198c27', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'isSanctioned': False, 'firstName': 'Karina', 'lastName': 'F', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Dmitry', 'lastName': 'S', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Jessy', 'lastName': 'J', 'countryCode': 'CA'}, {'isSanctioned': False, 'firstName': 'Farruh', 'lastName': 'K', 'countryCode': 'CA'}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.8, 'ratingColor': 'FFC800', 'ratingSignals': 11, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 3, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 3, 'items': [{'id': '53c7fe1511d29eaa20ae9367', 'createdAt': 1405615637, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3651954_wY_yB6E44JeNueg0HtOViI6w3xgPkI0cB1VfiZE5ke0.jpg', 'width': 960, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Mohammed', 'lastName': 'A', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '5234b63711d2d4fca1be0f95', 'createdAt': 1379186231, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/48226142_WbD-FEEvzbOMBqwyC5YNczqbWtWRdUJZB3Si1vqhyUs.jpg', 'width': 960, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Veronica', 'lastName': 'S', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1338667819, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '575abd10498ee9e376295c5b', 'createdAt': 1465564432, 'text': 'Avocado sushi pizza, tempura, bento box, edamame.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/575abd10498ee9e376295c5b', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'K', 'lastName': 'B', 'countryCode': 'CA'}, 'authorInteractionType': 'liked'}, {'id': '55b51717498e76e96eb2c650', 'createdAt': 1437931287, 'text': 'Cheap but not so tasty - they do have constant patrons.  This place is a hole in the wall.  It could also be cleaner.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/55b51717498e76e96eb2c650', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Alina', 'lastName': 'D', 'countryCode': 'CA'}, 'authorInteractionType': 'disliked'}]}]}, 'shortUrl': 'http://4sq.com/K3mNl7', 'timeZone': 'America/Toronto', 'listed': {'count': 1, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1, 'items': [{'id': '4 ...
#                          ID                     Name  Likes  Rating  Tips
# 0  4fca732be4b07c8e3e198c27  Miyako Sushi Restaurant      8     6.8     3
# ( 32 / 33 ) processed
# {'meta': {'code': 200, 'requestId': '5fc4ea329ec7747540096f8b'}, 'response': {'venue': {'id': '51049684e4b06b57cac4e3e8', 'name': 'Bazara', 'contact': {'phone': '6477480288', 'formattedPhone': '(647) 748-0288', 'twitter': 'bazarasushi'}, 'location': {'address': '188 Ossington', 'crossStreet': 'Roylat', 'lat': 43.64853491212856, 'lng': -79.4205209529485, 'labeledLatLngs': [{'label': 'display', 'lat': 43.64853491212856, 'lng': -79.4205209529485}], 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['188 Ossington (Roylat)', 'Toronto ON', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/bazara/51049684e4b06b57cac4e3e8', 'categories': [{'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 15}, 'url': 'http://bazara.ca', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 28, 'groups': [{'type': 'others', 'count': 28, 'items': []}], 'summary': '28 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 45, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 16, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 16, 'items': [{'id': '534899cb498e7e51ca7d443e', 'createdAt': 1397266891, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37179948_m5ZaqcUqWBFlrOCwW1CBMGDm5QYC7W0gOuiLPXsejLI.jpg', 'width': 640, 'height': 640, 'user': {'isSanctioned': False, 'firstName': 'Alice', 'lastName': 'P', 'countryCode': 'CA'}, 'visibility': 'public'}, {'id': '5348727d498e191822ffc513', 'createdAt': 1397256829, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37179948_XA9Ufzpnqcy-NFOo1iZ2A4SR9UTvGvHgNC3CvSbNi4E.jpg', 'width': 640, 'height': 640, 'user': {'isSanctioned': False, 'firstName': 'Alice', 'lastName': 'P', 'countryCode': 'CA'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1359255172, 'tips': {'count': 15, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 15, 'items': [{'id': '51295839e4b0447baa26605a', 'createdAt': 1361664057, 'text': 'The sashimi is very fresh and the wasabi is made from scratch.  Beautiful decor and cozy booths.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51295839e4b0447baa26605a', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'IAM Group', 'lastName': 'L', 'countryCode': 'PH'}, {'isSanctioned': False, 'firstName': 'Wang', 'countryCode': 'CA'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'winnie', 'lastName': 'l', 'countryCode': 'CA'}}, {'id': '54c1fd81498e64b8cdd1e9b9', 'createdAt': 1421999489, 'text': 'I love the wasabi here. So delightfully satisfying.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54c1fd81498e64b8cdd1e9b9', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': 'IAM Group', 'lastName': 'L', 'countryCode': 'PH'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'IAM Group', 'lastName': 'L', 'countryCode': 'PH'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/VaIGFP', 'timeZone': 'America/Toronto', 'listed': {'count': 52, 'groups': [{'type': 'others', 'name': 'Lists from other peopl ...
#                          ID    Name  Likes  Rating  Tips
# 0  51049684e4b06b57cac4e3e8  Bazara     28     8.1    15
# ( 33 / 33 ) processed
#              Borough                           Neighbourhood  \
# 28  Downtown Toronto  First Canadian Place, Underground city
# 29  Downtown Toronto  First Canadian Place, Underground city
# 30  Downtown Toronto  First Canadian Place, Underground city
# 31        North York                               Glencairn
# 32      West Toronto                Little Portugal, Trinity
#
#                           ID                      Name Likes  Rating Tips
# 28  5a4fdf56772fbc5e9fa73c7f              Chotto Matte    12     8.0    2
# 29  506a3830e4b0677a1f9d8eda             Ninki Izakaya     9     7.6    5
# 30  4afa1f33f964a520e91622e3  Fune Japanese Restaurant    53     7.6   27
# 31  4fca732be4b07c8e3e198c27   Miyako Sushi Restaurant     8     6.8    3
# 32  51049684e4b06b57cac4e3e8                    Bazara    28     8.1   15

# %%
japanese_rest_stats_t.shape
# Out:
# (33, 7)

# %% [markdown]
# # 2.2 Preparation for further analysis

# %%
japanese_rest_stats_t.dtypes
# Out:
# Borough           object
# Neighbourhood     object
# ID                object
# Name              object
# Likes             object
# Rating           float64
# Tips              object
# dtype: object

# %%
japanese_rest_stats_t['Likes'] = japanese_rest_stats_t['Likes'].astype('float64')
japanese_rest_stats_t['Tips'] = japanese_rest_stats_t['Tips'].astype('float64')
japanese_rest_stats_t.dtypes
# Out:
# Borough           object
# Neighbourhood     object
# ID                object
# Name              object
# Likes            float64
# Rating           float64
# Tips             float64
# dtype: object

# %% [markdown]
# We got all the Statistics for our 33 Japanese Restaurants

# %%
# Restaurant with maximum Likes

japanese_rest_stats_t.iloc[japanese_rest_stats_t['Likes'].idxmax()]
# Out:
# Borough                  Downtown Toronto
# Neighbourhood    Garden District, Ryerson
# ID               4b2bd898f964a52042bc24e3
# Name               Kinka Izakaya Original
# Likes                                 385
# Rating                                8.5
# Tips                                  220
# Name: 9, dtype: object

# %%
# Restaurant with maximum Ratings

japanese_rest_stats_t.iloc[japanese_rest_stats_t['Rating'].idxmax()]
# Out:
# Borough                                           Downtown Toronto
# Neighbourhood    Harbourfront East, Union Station, Toronto Islands
# ID                                        56201ed4498e7f700c462170
# Name                                                          Miku
# Likes                                                          142
# Rating                                                           9
# Tips                                                            47
# Name: 19, dtype: object

# %%
# Restaurant with maximum Tips

japanese_rest_stats_t.iloc[japanese_rest_stats_t['Tips'].idxmax()]
# Out:
# Borough                  Downtown Toronto
# Neighbourhood    Garden District, Ryerson
# ID               4b2bd898f964a52042bc24e3
# Name               Kinka Izakaya Original
# Likes                                 385
# Rating                                8.5
# Tips                                  220
# Name: 9, dtype: object

# %%
# We check the statistical values of our variables to make sure they are ready for our analysis

japanese_rest_stats_t.describe()
# Out:
#             Likes     Rating        Tips
# count   33.000000  33.000000   33.000000
# mean    47.000000   6.948485   25.636364
# std     71.343798   2.320307   40.873141
# min      0.000000   0.000000    0.000000
# 25%      9.000000   6.900000    3.000000
# 50%     21.000000   7.600000   11.000000
# 75%     53.000000   8.000000   33.000000
# max    385.000000   9.000000  220.000000

# %% [markdown]
# # 3. Visualization of neighbourhood with maximum average restaurant rating

# %%
t_neighborhood_stats=japanese_rest_stats_t.groupby('Neighbourhood', as_index=False).mean()[['Neighbourhood','Rating']]
t_neighborhood_stats.columns=['Neighbourhood','Average Rating']
t_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#                                         Neighbourhood  Average Rating
# 8   Harbourfront East, Union Station, Toronto Islands        9.000000
# 12                        St. James Town, Cabbagetown        8.400000
# 11                                     St. James Town        8.300000
# 9                            Little Portugal, Trinity        8.100000
# 2                      Commerce Court, Victoria Hotel        7.950000
# 14           Toronto Dominion Centre, Design Exchange        7.950000
# 13                                     Stn A PO Boxes        7.950000
# 6                            Garden District, Ryerson        7.800000
# 5              First Canadian Place, Underground city        7.775000
# 10                           Richmond, Adelaide, King        7.366667

# %% [markdown]
# These above are the average rating of restaurants by neighborhood

# %%
t_borough_stats=japanese_rest_stats_t.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
t_borough_stats.columns=['Borough','Average Rating']
t_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#             Borough  Average Rating
# 2      West Toronto        8.100000
# 0  Downtown Toronto        7.476923
# 1        North York        4.466667

# %% [markdown]
# Similarly, above average rating by boroughs

# %%
plt.title('Average rating of Japanese Restaurants for each Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
japanese_rest_stats_t.groupby('Borough').mean()['Rating'].plot(kind='bar', figsize=(14,6), color='navy')
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %%
# We will consider all the neighborhoods with average rating greater or equal 7.0 to visualize on a map
t_neighborhood_stats=t_neighborhood_stats[t_neighborhood_stats['Average Rating']>=7.0]
t_neighborhood_stats
# Out:
#                                         Neighbourhood  Average Rating
# 0                                  Central Bay Street        7.366667
# 1                                Church and Wellesley        7.266667
# 2                      Commerce Court, Victoria Hotel        7.950000
# 5              First Canadian Place, Underground city        7.775000
# 6                            Garden District, Ryerson        7.800000
# 8   Harbourfront East, Union Station, Toronto Islands        9.000000
# 9                            Little Portugal, Trinity        8.100000
# 10                           Richmond, Adelaide, King        7.366667
# 11                                     St. James Town        8.300000
# 12                        St. James Town, Cabbagetown        8.400000
# 13                                     Stn A PO Boxes        7.950000
# 14           Toronto Dominion Centre, Design Exchange        7.950000
# 16                        Willowdale, Willowdale East        7.000000

# %%
# We will join this Dataset to original Toronto data to get longitude and latitude
t_neighborhood_stats=pd.merge(t_neighborhood_stats,toronto_data, on='Neighbourhood')
t_neighborhood_stats=t_neighborhood_stats[['Borough','Neighbourhood','Latitude','Longitude','Average Rating']]
t_neighborhood_stats
# Out:
#              Borough                                      Neighbourhood  \
# 0   Downtown Toronto                                 Central Bay Street
# 1   Downtown Toronto                               Church and Wellesley
# 2   Downtown Toronto                     Commerce Court, Victoria Hotel
# 3   Downtown Toronto             First Canadian Place, Underground city
# 4   Downtown Toronto                           Garden District, Ryerson
# 5   Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 6       West Toronto                           Little Portugal, Trinity
# 7   Downtown Toronto                           Richmond, Adelaide, King
# 8   Downtown Toronto                                     St. James Town
# 9   Downtown Toronto                        St. James Town, Cabbagetown
# 10  Downtown Toronto                                     Stn A PO Boxes
# 11  Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 12        North York                        Willowdale, Willowdale East
#
#      Latitude  Longitude  Average Rating
# 0   43.657952 -79.387383        7.366667
# 1   43.665860 -79.383160        7.266667
# 2   43.648198 -79.379817        7.950000
# 3   43.648429 -79.382280        7.775000
# 4   43.657162 -79.378937        7.800000
# 5   43.640816 -79.381752        9.000000
# 6   43.647927 -79.419750        8.100000
# 7   43.650571 -79.384568        7.366667
# 8   43.651494 -79.375418        8.300000
# 9   43.667967 -79.367675        8.400000
# 10  43.646435 -79.374846        7.950000
# 11  43.647177 -79.381576        7.950000
# 12  43.770120 -79.408493        7.000000

# %% [markdown]
# Now we will show above data applied to the map

# %% [markdown]
# # Final Step: Visualization

# %%
# Create map and display it

t_map = folium.Map(location=geo_location('Toronto'), zoom_start=12)

# instantiate a feature group for the ratings in the dataframe

rating = folium.map.FeatureGroup()

# loop through the ratings and add each to the neighborhood feature group

for lat, lng, in t_neighborhood_stats[['Latitude','Longitude']].values:
    rating.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
t_neighborhood_stats['Label']=t_neighborhood_stats['Neighbourhood']+', '+t_neighborhood_stats['Borough']+'('+t_neighborhood_stats['Average Rating'].map(str)+')'

# add pop-up text to each marker on the map

for lat, lng, label in t_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(t_map)
    
# add ratings to map

t_map.add_child(rating)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, in the city of Toronto there are only 33 Japanese Restaurants. For better results we have limited our research to higher rated Japanese Restaurants, specifically, starting from 7.0 on a 1.0 to 10.0 scale. Overall, majority of Restaurants located in Downtown Toronto, few are in West Toronto and lowest rated ones in North York. For ease of market entrance I would recommend West Toronto to potential investors due to less competitiveness in the area. For better results, improvements to this analysis can be applied.
